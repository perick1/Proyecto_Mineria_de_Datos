# %%
import os
import numpy as np
import seaborn
import pandas as pd

print(os.getcwd())

todata = "../Data/"
df1 = pd.read_csv(todata + "2011.csv")
df5 = pd.read_csv(todata + "2015.csv")
df9 = pd.read_csv(todata + "2019.csv")
# Out:
# d:\Proyectos\Python_proyects\Mineria_Datos\Scripts

# %%
#df1.info()
corr = df1.select_dtypes("number").corr()
seaborn.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr = df5.select_dtypes("number").corr()
seaborn.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr = df9.select_dtypes("number").corr()
seaborn.heatmap(corr)
# Out:
# <AxesSubplot:>
